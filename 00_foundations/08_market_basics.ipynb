# %% [markdown]
# # Market Data Basics
#
# Markets connect security fundamentals with investor expectations. This notebook builds on equity and bond basics by introducing the market data concepts needed before working with open-high-low-close-volume data, returns, indicators, and portfolio construction.
#
# Abbreviations used in this notebook:
#
# - **OHLCV**: Open, High, Low, Close, Volume; the standard daily market data fields.
# - **VWAP**: Volume-Weighted Average Price, the average traded price weighted by volume.
# - **CHF**: Swiss franc, the currency used in the examples.

# %% [markdown]
# ## 1. Intuition
#
# A market price is the current clearing price where buyers and sellers agree to transact. For equities, the quoted price is the price of one share. It changes when investors update their expectations about future cash flows, risk, interest rates, liquidity, or sentiment.
#
# Key market concepts:
#
# - **Price**: the last traded value of one share.
# - **Market capitalization**: total equity value implied by the share price.
# - **Bid and ask**: the best price buyers offer and sellers request.
# - **Spread**: the transaction cost between bid and ask.
# - **Volume**: number of shares traded.
# - **Return**: percentage change in value over a period.
# - **Volatility**: variation in returns, often used as a risk proxy.
# - **Beta**: sensitivity of a stock's returns to movements in the overall market.
#
# > Volatility and beta are related, but they are not the same. Volatility measures how much a stock moves on its own. Beta measures how much it tends to move with the market. A beta above 1 means the stock has historically moved more than the market; a beta below 1 means it has moved less.
#
# Fundamentals help estimate value. Markets show how investors price that value right now.

# %% [markdown]
# ### Equity vs Bond Market Data
#
# Equity market data is usually share-based and exchange-centered. Bond market data is more instrument-specific, yield-centered, and often over-the-counter.
#
# Equities commonly use:
#
# - **Ticker**: short symbol for the listed share.
# - **Exchange or trading venue**: place where the share is listed or traded.
# - **Share price**: price per common share.
# - **OHLCV**: open, high, low, close, and volume.
# - **Bid and ask**: visible prices for liquid listed shares.
# - **Market capitalization**: share price multiplied by shares outstanding.
#
# Bonds commonly use:
#
# - **ISIN or CUSIP**: security identifier for a specific bond issue.
# - **Issuer**: company, government, or institution that borrowed the money.
# - **Coupon rate and maturity date**: contractual cash-flow terms.
# - **Clean price and dirty price**: quoted price excluding accrued interest versus settlement price including accrued interest.
# - **Accrued interest**: coupon interest earned since the last coupon date.
# - **Yield and spread**: return and compensation over a reference curve.
# - **Duration and rating**: interest-rate sensitivity and credit quality.
#
# The same market concepts exist in both markets, such as price, bid, ask, spread, volume, return, and liquidity. But they are interpreted differently. For bonds, the quoted price may be a clean price, settlement usually uses the dirty price, and the last traded price may be stale if the bond is illiquid. Bond pricing mechanics are covered in the Bond Basics notebook; this notebook focuses on market data concepts across traded instruments.

# %% [markdown]
# ## 2. Mathematics
#
# **Market capitalization:**
#
# $$
# \text{Market Cap} = \text{Share Price} \times \text{Shares Outstanding}
# $$
#
# Where:
#
# - $\text{Shares Outstanding}$ = number of shares issued and outstanding
# - $\text{Share Price}$ = market price per share
# - $\text{Market Cap}$ = equity market value
#
# **Simple return:**
#
# $$
# R_t = \frac{P_t - P_{t-1}}{P_{t-1}}
# $$
#
# Where:
#
# - $R_t$ = simple return at time $t$
# - $P_t$ = price at time $t$
# - $P_{t-1}$ = price in the previous period
# - $t$ = time period index
#
# **Log return:**
#
# $$
# r_t = \ln\left(\frac{P_t}{P_{t-1}}\right)
# $$
#
# Where:
#
# - $r_t$ = log return at time $t$
# - $P_t$ = price at time $t$
# - $P_{t-1}$ = price in the previous period
# - $t$ = time period index
#
# **Bid-ask spread:**
#
# $$
# \text{Spread} = Ask - Bid
# $$
#
# Where:
#
# - $Ask$ = lowest price sellers are willing to accept
# - $Bid$ = highest price buyers are willing to pay
# - $Spread$ = ask price minus bid price
#
# **Relative spread:**
#
# $$
# \text{Relative Spread} = \frac{Ask - Bid}{Midpoint}
# $$
#
# Where:
#
# - $Ask$ = lowest price sellers are willing to accept
# - $Bid$ = highest price buyers are willing to pay
# - $Midpoint$ = average of bid and ask prices
# - $Spread$ = ask price minus bid price
#
# **Volume-weighted average price:**
#
# $$
# VWAP = \frac{\sum_t Price_t \times Volume_t}{\sum_t Volume_t}
# $$
#
# Where:
#
# - $VWAP$ = volume-weighted average price
# - $Price_t$ = transaction or close price at time $t$
# - $Volume_t$ = traded volume at time $t$
# - $t$ = time period index
#
# **Daily volatility from daily returns:**
#
# $$
# \sigma_{daily} = \sqrt{\frac{1}{n - 1}\sum_{t=1}^{n}\left(R_t - \bar{R}\right)^2}
# $$
#
# Where:
#
# - $\sigma_{daily}$ = daily volatility
# - $R_t$ = simple return on day $t$
# - $\bar{R}$ = average daily return
# - $n$ = number of daily return observations
#
# **Annualized volatility from daily returns:**
#
# $$
# \sigma_{annual} = \sigma_{daily} \times \sqrt{252}
# $$
#
# Where:
#
# - $\sigma_{annual}$ = annualized volatility
# - $\sigma_{daily}$ = daily volatility
# - $252$ = approximate number of trading days in one year
#
# > Annualized volatility converts daily return volatility into a yearly risk estimate. The multiplier is $\sqrt{252}$, not $252$, because variance scales approximately with time, while volatility is the square root of variance. If daily variance is multiplied by 252 trading days, daily volatility is multiplied by $\sqrt{252}$. The estimate can be recalculated each day using a rolling window of recent daily returns, but the formula itself is a conversion from daily volatility to annual volatility.

# %% [markdown]
# ## 3. Implementation
#
# We will create a small synthetic market dataset for a defensive consumer company. The goal is not price prediction; the goal is to understand market data fields and the calculations built on top of them.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-whitegrid")
pd.options.display.float_format = "{:,.4f}".format
np.random.seed(7)

trading_days = pd.bdate_range("2024-01-02", periods=90)
start_price = 105.0
shares_outstanding = 2_650_000_000

returns = np.random.normal(loc=0.00035, scale=0.011, size=len(trading_days))
close = start_price * np.cumprod(1 + returns)
open_price = close * (1 + np.random.normal(0, 0.003, len(trading_days)))
high = np.maximum(open_price, close) * (1 + np.random.uniform(0.001, 0.012, len(trading_days)))
low = np.minimum(open_price, close) * (1 - np.random.uniform(0.001, 0.012, len(trading_days)))
volume = np.random.randint(1_200_000, 4_800_000, len(trading_days))
spread = np.random.uniform(0.02, 0.12, len(trading_days))

market = pd.DataFrame({
    "date": trading_days,
    "open": open_price,
    "high": high,
    "low": low,
    "close": close,
    "volume": volume,
    "bid": close - spread / 2,
    "ask": close + spread / 2,
})

market["midpoint"] = (market["bid"] + market["ask"]) / 2
market["simple_return"] = market["close"].pct_change()
market["log_return"] = np.log(market["close"] / market["close"].shift(1))
market["market_cap"] = market["close"] * shares_outstanding
market["spread"] = market["ask"] - market["bid"]
market["relative_spread"] = market["spread"] / market["midpoint"]
market["traded_value"] = market["close"] * market["volume"]

market.head().style.format({
    "open": "CHF {:,.2f}",
    "high": "CHF {:,.2f}",
    "low": "CHF {:,.2f}",
    "close": "CHF {:,.2f}",
    "volume": "{:,.0f}",
    "bid": "CHF {:,.2f}",
    "ask": "CHF {:,.2f}",
    "midpoint": "CHF {:,.2f}",
    "simple_return": "{:.2%}",
    "log_return": "{:.2%}",
    "market_cap": "CHF {:,.0f}",
    "spread": "CHF {:,.2f}",
    "relative_spread": "{:.3%}",
    "traded_value": "CHF {:,.0f}",
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_6edc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6edc2_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_6edc2_level0_col1" class="col_heading level0 col1" >open</th>
#       <th id="T_6edc2_level0_col2" class="col_heading level0 col2" >high</th>
#       <th id="T_6edc2_level0_col3" class="col_heading level0 col3" >low</th>
#       <th id="T_6edc2_level0_col4" class="col_heading level0 col4" >close</th>
#       <th id="T_6edc2_level0_col5" class="col_heading level0 col5" >volume</th>
#       <th id="T_6edc2_level0_col6" class="col_heading level0 col6" >bid</th>
#       <th id="T_6edc2_level0_col7" class="col_heading level0 col7" >ask</th>
#       <th id="T_6edc2_level0_col8" class="col_heading level0 col8" >midpoint</th>
#       <th id="T_6edc2_level0_col9" class="col_heading level0 col9" >simple_return</th>
#       <th id="T_6edc2_level0_col10" class="col_heading level0 col10" >log_return</th>
#       <th id="T_6edc2_level0_col11" class="col_heading level0 col11" >market_cap</th>
#       <th id="T_6edc2_level0_col12" class="col_heading level0 col12" >spread</th>
#       <th id="T_6edc2_level0_col13" class="col_heading level0 col13" >relative_spread</th>
#       <th id="T_6edc2_level0_col14" class="col_heading level0 col14" >traded_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6edc2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6edc2_row0_col0" class="data row0 col0" >2024-01-02 00:00:00</td>
#       <td id="T_6edc2_row0_col1" class="data row0 col1" >CHF 107.17</td>
#       <td id="T_6edc2_row0_col2" class="data row0 col2" >CHF 108.20</td>
#       <td id="T_6edc2_row0_col3" class="data row0 col3" >CHF 106.44</td>
#       <td id="T_6edc2_row0_col4" class="data row0 col4" >CHF 106.99</td>
#       <td id="T_6edc2_row0_col5" class="data row0 col5" >2,274,142</td>
#       <td id="T_6edc2_row0_col6" class="data row0 col6" >CHF 106.95</td>
#       <td id="T_6edc2_row0_col7" class="data row0 col7" >CHF 107.03</td>
#       <td id="T_6edc2_row0_col8" class="data row0 col8" >CHF 106.99</td>
#       <td id="T_6edc2_row0_col9" class="data row0 col9" >nan%</td>
#       <td id="T_6edc2_row0_col10" class="data row0 col10" >nan%</td>
#       <td id="T_6edc2_row0_col11" class="data row0 col11" >CHF 283,521,664,048</td>
#       <td id="T_6edc2_row0_col12" class="data row0 col12" >CHF 0.08</td>
#       <td id="T_6edc2_row0_col13" class="data row0 col13" >0.076%</td>
#       <td id="T_6edc2_row0_col14" class="data row0 col14" >CHF 243,308,877</td>
#     </tr>
#     <tr>
#       <th id="T_6edc2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6edc2_row1_col0" class="data row1 col0" >2024-01-03 00:00:00</td>
#       <td id="T_6edc2_row1_col1" class="data row1 col1" >CHF 106.69</td>
#       <td id="T_6edc2_row1_col2" class="data row1 col2" >CHF 106.97</td>
#       <td id="T_6edc2_row1_col3" class="data row1 col3" >CHF 105.46</td>
#       <td id="T_6edc2_row1_col4" class="data row1 col4" >CHF 106.48</td>
#       <td id="T_6edc2_row1_col5" class="data row1 col5" >3,767,387</td>
#       <td id="T_6edc2_row1_col6" class="data row1 col6" >CHF 106.45</td>
#       <td id="T_6edc2_row1_col7" class="data row1 col7" >CHF 106.51</td>
#       <td id="T_6edc2_row1_col8" class="data row1 col8" >CHF 106.48</td>
#       <td id="T_6edc2_row1_col9" class="data row1 col9" >-0.48%</td>
#       <td id="T_6edc2_row1_col10" class="data row1 col10" >-0.48%</td>
#       <td id="T_6edc2_row1_col11" class="data row1 col11" >CHF 282,167,759,905</td>
#       <td id="T_6edc2_row1_col12" class="data row1 col12" >CHF 0.06</td>
#       <td id="T_6edc2_row1_col13" class="data row1 col13" >0.056%</td>
#       <td id="T_6edc2_row1_col14" class="data row1 col14" >CHF 401,145,340</td>
#     </tr>
#     <tr>
#       <th id="T_6edc2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6edc2_row2_col0" class="data row2 col0" >2024-01-04 00:00:00</td>
#       <td id="T_6edc2_row2_col1" class="data row2 col1" >CHF 106.55</td>
#       <td id="T_6edc2_row2_col2" class="data row2 col2" >CHF 107.63</td>
#       <td id="T_6edc2_row2_col3" class="data row2 col3" >CHF 106.21</td>
#       <td id="T_6edc2_row2_col4" class="data row2 col4" >CHF 106.55</td>
#       <td id="T_6edc2_row2_col5" class="data row2 col5" >1,356,442</td>
#       <td id="T_6edc2_row2_col6" class="data row2 col6" >CHF 106.54</td>
#       <td id="T_6edc2_row2_col7" class="data row2 col7" >CHF 106.57</td>
#       <td id="T_6edc2_row2_col8" class="data row2 col8" >CHF 106.55</td>
#       <td id="T_6edc2_row2_col9" class="data row2 col9" >0.07%</td>
#       <td id="T_6edc2_row2_col10" class="data row2 col10" >0.07%</td>
#       <td id="T_6edc2_row2_col11" class="data row2 col11" >CHF 282,368,387,334</td>
#       <td id="T_6edc2_row2_col12" class="data row2 col12" >CHF 0.03</td>
#       <td id="T_6edc2_row2_col13" class="data row2 col13" >0.033%</td>
#       <td id="T_6edc2_row2_col14" class="data row2 col14" >CHF 144,534,468</td>
#     </tr>
#     <tr>
#       <th id="T_6edc2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6edc2_row3_col0" class="data row3 col0" >2024-01-05 00:00:00</td>
#       <td id="T_6edc2_row3_col1" class="data row3 col1" >CHF 107.04</td>
#       <td id="T_6edc2_row3_col2" class="data row3 col2" >CHF 107.86</td>
#       <td id="T_6edc2_row3_col3" class="data row3 col3" >CHF 106.38</td>
#       <td id="T_6edc2_row3_col4" class="data row3 col4" >CHF 107.07</td>
#       <td id="T_6edc2_row3_col5" class="data row3 col5" >3,464,119</td>
#       <td id="T_6edc2_row3_col6" class="data row3 col6" >CHF 107.04</td>
#       <td id="T_6edc2_row3_col7" class="data row3 col7" >CHF 107.10</td>
#       <td id="T_6edc2_row3_col8" class="data row3 col8" >CHF 107.07</td>
#       <td id="T_6edc2_row3_col9" class="data row3 col9" >0.48%</td>
#       <td id="T_6edc2_row3_col10" class="data row3 col10" >0.48%</td>
#       <td id="T_6edc2_row3_col11" class="data row3 col11" >CHF 283,732,983,142</td>
#       <td id="T_6edc2_row3_col12" class="data row3 col12" >CHF 0.06</td>
#       <td id="T_6edc2_row3_col13" class="data row3 col13" >0.054%</td>
#       <td id="T_6edc2_row3_col14" class="data row3 col14" >CHF 370,899,931</td>
#     </tr>
#     <tr>
#       <th id="T_6edc2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6edc2_row4_col0" class="data row4 col0" >2024-01-08 00:00:00</td>
#       <td id="T_6edc2_row4_col1" class="data row4 col1" >CHF 105.96</td>
#       <td id="T_6edc2_row4_col2" class="data row4 col2" >CHF 106.62</td>
#       <td id="T_6edc2_row4_col3" class="data row4 col3" >CHF 105.74</td>
#       <td id="T_6edc2_row4_col4" class="data row4 col4" >CHF 106.18</td>
#       <td id="T_6edc2_row4_col5" class="data row4 col5" >3,005,865</td>
#       <td id="T_6edc2_row4_col6" class="data row4 col6" >CHF 106.15</td>
#       <td id="T_6edc2_row4_col7" class="data row4 col7" >CHF 106.20</td>
#       <td id="T_6edc2_row4_col8" class="data row4 col8" >CHF 106.18</td>
#       <td id="T_6edc2_row4_col9" class="data row4 col9" >-0.83%</td>
#       <td id="T_6edc2_row4_col10" class="data row4 col10" >-0.84%</td>
#       <td id="T_6edc2_row4_col11" class="data row4 col11" >CHF 281,370,011,358</td>
#       <td id="T_6edc2_row4_col12" class="data row4 col12" >CHF 0.05</td>
#       <td id="T_6edc2_row4_col13" class="data row4 col13" >0.049%</td>
#       <td id="T_6edc2_row4_col14" class="data row4 col14" >CHF 319,154,819</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The most common daily market data format is **OHLCV**, which means open, high, low, close, and volume. These fields are the raw material for later notebooks on indicators and backtesting.

# %%
summary_display = pd.DataFrame({
    "metric": [
        "Start close",
        "End close",
        "Total return",
        "Average daily return",
        "Daily volatility",
        "Annualized volatility",
        "Average volume",
        "Average relative spread",
        "Latest market cap",
    ],
    "value": [
        f"CHF {market['close'].iloc[0]:,.2f}",
        f"CHF {market['close'].iloc[-1]:,.2f}",
        f"{market['close'].iloc[-1] / market['close'].iloc[0] - 1:.1%}",
        f"{market['simple_return'].mean():.3%}",
        f"{market['simple_return'].std():.2%}",
        f"{market['simple_return'].std() * np.sqrt(252):.1%}",
        f"{market['volume'].mean():,.0f} shares",
        f"{market['relative_spread'].mean():.3%}",
        f"CHF {market['market_cap'].iloc[-1] / 1_000_000_000:,.1f}bn",
    ],
})
summary_display
# Out:
#                     metric             value
# 0              Start close        CHF 106.99
# 1                End close        CHF 105.95
# 2             Total return             -1.0%
# 3     Average daily return           -0.005%
# 4         Daily volatility             1.13%
# 5    Annualized volatility             18.0%
# 6           Average volume  2,807,834 shares
# 7  Average relative spread            0.070%
# 8        Latest market cap       CHF 280.8bn

# %% [markdown]
# > Volatility is calculated from returns, not from price levels. In Python, the daily volatility is the standard deviation of daily returns. Annualized volatility scales that daily value by $\sqrt{252}$ to express the same risk estimate on a yearly trading-day basis.

# %%
daily_returns = market["simple_return"].dropna()

daily_volatility = daily_returns.std()
annualized_volatility = daily_volatility * np.sqrt(252)

print(f"Daily volatility: {daily_volatility:.2%}")
print(f"Annualized volatility: {annualized_volatility:.1%}")
# Out:
# Daily volatility: 1.13%
# Annualized volatility: 18.0%

# %%
vwap = market["traded_value"].sum() / market["volume"].sum()
latest_close = market["close"].iloc[-1]

print(f"VWAP over sample: CHF {vwap:,.2f}")
print(f"Latest close: CHF {latest_close:,.2f}")
print(f"Latest market cap: CHF {market['market_cap'].iloc[-1] / 1_000_000_000:,.1f}bn")
# Out:
# VWAP over sample: CHF 103.21
# Latest close: CHF 105.95
# Latest market cap: CHF 280.8bn

# %% [markdown]
# ## 4. Visualization
#
# Market charts help reveal price trend, trading activity, and day-to-day return behavior. They are descriptive, not proof of intrinsic value. A common OHLCV visualization is a candlestick chart with volume bars underneath.

# %%
plot_data = market.tail(40).copy()
x = np.arange(len(plot_data))
candle_width = 0.6

fig, axes = plt.subplots(2, 1, figsize=(12, 7), sharex=True, gridspec_kw={"height_ratios": [3, 1]})

for i, row in enumerate(plot_data.itertuples()):
    color = "#2f6f8f" if row.close >= row.open else "#9a3d2f"
    lower = min(row.open, row.close)
    height = abs(row.close - row.open)

    axes[0].vlines(i, row.low, row.high, color=color, linewidth=1)
    axes[0].bar(i, height, bottom=lower, width=candle_width, color=color, edgecolor=color)

axes[0].set_title("Candlestick Chart with Volume")
axes[0].set_ylabel("CHF per share")

volume_colors = np.where(plot_data["close"] >= plot_data["open"], "#2f6f8f", "#9a3d2f")
axes[1].bar(x, plot_data["volume"], color=volume_colors, alpha=0.8)
axes[1].set_ylabel("Volume")
axes[1].set_xlabel("Date")

tick_positions = x[::5]
tick_labels = plot_data["date"].dt.strftime("%b %d").iloc[::5]
axes[1].set_xticks(tick_positions)
axes[1].set_xticklabels(tick_labels, rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(11, 7), sharex=True, gridspec_kw={"height_ratios": [2, 1]})

axes[0].plot(market["date"], market["close"], color="#2f6f8f", label="Close")
axes[0].fill_between(market["date"], market["low"], market["high"], color="#2f6f8f", alpha=0.18, label="Daily range")
axes[0].set_title("Synthetic Stock Price: Close and Daily Range")
axes[0].set_ylabel("CHF per share")
axes[0].legend(loc="upper left")

axes[1].bar(market["date"], market["volume"], color="#9a6b2f", alpha=0.8)
axes[1].set_title("Trading Volume")
axes[1].set_ylabel("Shares")
axes[1].set_xlabel("Date")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

axes[0].hist(market["simple_return"].dropna(), bins=18, color="#2f6f8f", edgecolor="white")
axes[0].axvline(0, color="black", linewidth=1)
axes[0].set_title("Daily Return Distribution")
axes[0].set_xlabel("Daily return")
axes[0].set_ylabel("Count")
axes[0].xaxis.set_major_formatter(lambda x, pos: f"{x:.1%}")

axes[1].plot(market["date"], market["relative_spread"], color="#9a6b2f")
axes[1].set_title("Relative Bid-Ask Spread")
axes[1].set_xlabel("Date")
axes[1].set_ylabel("Spread / Midpoint")
axes[1].yaxis.set_major_formatter(lambda x, pos: f"{x:.2%}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Application
#
# When looking at a stock such as Nestle, market basics help connect company analysis to tradable reality:
#
# - Market cap tells us the equity value implied by the current share price.
# - Returns show how the price changed over time.
# - Volatility gives a first approximation of market risk.
# - Volume helps us understand liquidity.
# - Bid-ask spread indicates transaction cost and trading friction.
# - VWAP is useful when evaluating execution quality over a trading window.
#
# This is the bridge from fundamental analysis to market data. In later notebooks, these fields become inputs for indicators, portfolio risk, and backtests.

# %%
latest = market.iloc[-1]
prior = market.iloc[0]

interpretation = pd.DataFrame({
    "metric": [
        "Price change",
        "Total return",
        "Latest bid",
        "Latest ask",
        "Latest spread",
        "Latest relative spread",
        "Latest traded value",
    ],
    "value": [
        f"CHF {latest['close'] - prior['close']:,.2f}",
        f"{latest['close'] / prior['close'] - 1:.1%}",
        f"CHF {latest['bid']:,.2f}",
        f"CHF {latest['ask']:,.2f}",
        f"CHF {latest['spread']:,.2f}",
        f"{latest['relative_spread']:.3%}",
        f"CHF {latest['traded_value'] / 1_000_000:,.1f}m",
    ],
})

interpretation
# Out:
#                    metric       value
# 0            Price change   CHF -1.04
# 1            Total return       -1.0%
# 2              Latest bid  CHF 105.94
# 3              Latest ask  CHF 105.96
# 4           Latest spread    CHF 0.03
# 5  Latest relative spread      0.025%
# 6     Latest traded value  CHF 145.2m

# %% [markdown]
# ## 6. Reflection
#
# - Price is what the market currently pays; value is what analysis tries to estimate.
# - Market cap converts a per-share price into total equity value.
# - Returns, not price levels, are the usual input for risk and portfolio analysis.
# - Volume and spread matter because investing also depends on liquidity and transaction costs.
# - OHLCV data is the foundation for market data pipelines, technical indicators, and backtests.
#
# Questions to answer after running the notebook:
#
# 1. Why is market cap more useful than share price alone?
# 2. Why do analysts usually study returns instead of raw prices?
# 3. What does a wider bid-ask spread tell you about liquidity?
# 4. How can a stock price move even when company fundamentals have not changed?
